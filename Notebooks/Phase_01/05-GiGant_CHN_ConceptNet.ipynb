# %%
import gensim
import pandas as pd
import spacy
import numpy as np
from wefe.word_embedding_model import WordEmbeddingModel
from wefe.metrics import RIPA
from wefe.query import Query
import re
from gensim.models import KeyedVectors

# %%
embeddings_file = "/Users/matthijstentije/University/MSc_Data-Science/Thesis/MSc_Data_Science_Thesis/data/numberbatch-19.08.txt.gz"

print("Loading Numberbatch embeddings...")
original_model = gensim.models.KeyedVectors.load_word2vec_format(embeddings_file, binary=False)
print("Embeddings loaded!")

# Clean Tokens
def further_clean(token):
    token = token.replace('#', '').replace('_', ' ')
    token = re.sub(r'^\d+\s*', '', token)
    token = re.sub(r'\d+', '', token)
    token = token.strip(".,;:!?\"'")
    token = re.sub(r'\s+', ' ', token)
    token = token.strip()
    return token

# Filter en schoon Nederlandse tokens
prefix = '/c/nl/'
cleaned_words = {}
for word in original_model.index_to_key:
    if word.startswith(prefix):
        clean_word = further_clean(word[len(prefix):])
        if clean_word and len(clean_word) > 1 and not re.match(r'^[A-Za-z]\s', clean_word):
            # Gebruik alleen woorden die nog niet in de dictionary zitten
            if clean_word not in cleaned_words:
                cleaned_words[clean_word] = original_model[word]

print(f"Number of unique NL tokens: {len(cleaned_words)}")

# Maak een nieuw KeyedVectors-model aan
vector_size = original_model.vector_size
nl_model = KeyedVectors(vector_size=vector_size)

# Voeg de opgeschoonde Nederlandse vectors toe
for word, vec in cleaned_words.items():
    nl_model.add_vector(word, vec)

print(f"Clean model with number of {len(nl_model.index_to_key)} tokens!")

nl_model.save_word2vec_format("nl_numberbatch.bin", binary=True)
# Out:
# Loading Numberbatch embeddings...

# %%
nl_model = KeyedVectors.load_word2vec_format("nl_numberbatch.txt", binary=False)

# %%
# Load spaCy Dutch NLP model
nlp = spacy.load('nl_core_news_lg')

# %%
df = pd.read_csv("/Users/matthijstentije/University/MSc_Data-Science/Thesis/MSc_Data_Science_Thesis/data/Corpus_Hedendaags_Nederlands_Adjectives.csv", sep=";")

# %%
# -----------------------
# 3. Your CSV adjective extraction function
def extract_adjectives_from_csv(file_path):
    """
    Reads a CSV file (with phrases/word groups in the first column),
    parses each phrase with spaCy to extract adjectives (ADJ),
    lemmatizes them, and returns a list of unique, lowercased adjectives.
    """
    df = pd.read_csv(file_path, delimiter=';', usecols=[0], names=["Group"], header=0)
    df.dropna(subset=["Group"], inplace=True)
    adjectives = []
    for phrase in df["Group"]:
        doc = nlp(phrase)
        for token in doc:
            if token.pos_ == "ADJ" and token.is_alpha:
                adjectives.append(token.lemma_.lower())
    adjectives = list(dict.fromkeys(adjectives))  # Remove duplicates while preserving order
    return adjectives

# -----------------------
# 4. Use the CSV file path
csv_file_path = "/Users/matthijstentije/University/MSc_Data-Science/Thesis/MSc_Data_Science_Thesis/data/Corpus_Hedendaags_Nederlands_Adjectives.csv"
result_adjectives = extract_adjectives_from_csv(csv_file_path)
print("Extracted adjectives from CSV:", result_adjectives[:10])
print("Total unique adjectives:", len(result_adjectives))

# -----------------------
# 5. Compare Extracted Adjectives with Cleaned Embeddings
missing_words = [word for word in result_adjectives if word not in nl_model]
print(f"Total missing words: {len(missing_words)}")
print("Sample missing words:", missing_words[:10])

# Hou alleen adjectives die in het embedding model zitten
filtered_adjectives = [word for word in result_adjectives if word in nl_model]

# (Optioneel) filter uit op basis van substrings in target-woorden
target_words = [
    "man", "kerel", "jongen", "vader", "zoon", "vent", "gast", "meneer", "opa", "oom",
    "vrouw", "dame", "meisje", "moeder", "dochter", "tante", "oma", "mevrouw", "meid"
]

filtered_adjectives = [
    adj for adj in filtered_adjectives if not any(target in adj for target in target_words)
]

print(f"Remaining adjectives after final filtering: {len(filtered_adjectives)}")
print("Sample:", filtered_adjectives[:10])
# Out:
# Total cleaned Dutch embeddings: 190099
# Extracted adjectives from CSV: ['groot', 'vreemd', 'prachtig', 'onschuldig', 'vrouwelijk', 'angstig', 'koppig', 'uitzonderlijk', 'verkiesbaar', 'wilsonbekwame', 'ongerust', 'polygaum', 'wereldwijaz', 'praatgraag', 'teder', 'grof', 'grooot', 'schimmig', 'wereldwijze', 'polygame', 'onvriendelijk', 'wantrouwen', 'vervaarlijk', 'eervol', 'onsterfelijk', 'snobistisch', 'heimelijk', 'atypisch', 'wilsonbekwaam', 'wantrouwend', 'tegenstrijdig', 'rafelig', 'wereldwijs', 'polygaam', 'nadenken', 'panisch', 'onbestemd', 'eindig', 'onzelfzuchtig', 'droogkomisch', 'maatschappijkritisch', 'diepzinnig', 'vreemder', 'hondsbrutaal', 'ongrondwettig', 'etherisch', 'onalledaags', 'prinselijk', 'extern', 'onwerkelijk', 'wisselvallig', 'tumultueus', 'levenskrachtig', 'contraproductief', 'ongerussen', 'afdoende', 'pronkzuchtig', 'stemmig', 'mannek', 'wiebelig', 'geelgroen', 'grover', 'hengstig', 'gortdroog', 'zuidwaarts', 'manneke', 'geestelijk', 'alleenstaan', 'afwezig', 'gemiddeld', 'streng', 'louter', 'katholiek', 'rechts', 'servisch', 'specifiek', 'enorm', 'gematigd', 'ruig', 'kleurloos', 'zwartharig', 'orthodox', 'diepgelovig', 'slapap', 'bozig', 'formeel', 'oppermachtig', 'straatarm', 'alleenstaand', 'rechtser', 'psychiatrisch', 'seren', 'bomvol', 'gloednieuw', 'inventief', 'slordig', 'mistroostig', 'finaal', 'afstotelijk', 'tactisch', 'grofgebekt', 'milieubewust', 'ellendig', 'slappe', 'kien', 'onbevoegd', 'vinnig', 'impopulair', 'trendgevoelig', 'slapper', 'ruiger', 'slap', 'omzichtig', 'chemisch', 'opportuun', 'schutterig', 'bloedig', 'toonbaar', 'gematigder', 'aartslelijk', 'lauw', 'plaatsvervangend', 'onverenigbaar', 'onvolledig', 'geestelijke', 'kieen', 'sereen', 'onuitroeibaar', 'querulante', 'milieubewuster', 'milieubewu', 'kruimelig', 'behaaglijk', 'pregnant', 'wit', 'bijzonder', 'vijftienjarig', 'slim', 'uitsluitend', 'gewelddadig', 'vrolijk', 'lastig', 'vermogend', 'inheems', 'aanwezig', 'stevig', 'commercieel', 'dapper', 'anoniem', 'volledig', 'serieus', 'internationaal', 'breed', 'naamloos', 'individueel', 'progressief', 'mollig', 'stugge', 'indrukwekkend', 'pittig', 'religieus', 'begaafd', 'onecht', 'wereldvreemd', 'opmerkelijk', 'olympisch', 'absoluut', 'volwaardig', 'driftig', 'kundig', 'maximaal', 'plezierig', 'willig', 'dominicaans', 'constant', 'seksistisch', 'literair', 'woest', 'lieftallig', 'negentigjarig', 'dierbaar', 'mentaal', 'oostwaarts', 'corrupt', 'luidkeels', 'onwillig', 'serieuz', 'instabiel', 'onmiskenbaar', 'gedeeltelijk', 'ongelovig', 'vurig', 'studentikoos', 'thuisloos', 'dol', 'wekenlang', 'seksloos', 'traag', 'verbazingwekkend', 'slimmer', 'collectief', 'alert', 'engelstalig', 'wilsbekwaam', 'eenarmig', 'missen', 'wezenloos', 'present', 'paniekerig', 'kunstzinnig', 'goddeloos', 'schaamteloos', 'lastigst', 'inzetbaar', 'bred', 'grootstedelijk', 'spaanstalig', 'opmerkelijkst', 'dof', 'godsdienstig', 'incidenteel', 'minutieus', 'mis', 'hedonistisch', 'happig', 'gehavend', 'gelijkmatig', 'stug', 'fijnbesnaard', 'nauwkeurig', 'mouwloos', 'gelukzalig', 'vijandig', 'blits', 'onbenullig', 'onrechtvaardig', 'lieflijk', 'onbeschermd', 'onveranderd', 'alerter', 'elektronisch', 'sprieterig', 'doff', 'evangelisch', 'parlementair', 'cognitief', 'kouwelijk', 'priesterlijk', 'attractief', 'vermogennen', 'flinterdun', 'staatsgevaarlijk', 'zinvol', 'kortademig', 'evident', 'verzot', 'ostentatief', 'benard', 'directief', 'afkerig', 'breod', 'ongelijksoortig', 'klantgerichte', 'dofef', 'laks', 'goor', 'warmhartig', 'eerloos', 'dominicaanse', 'gitzwart', 'vulkanisch', 'onverhoeds', 'duizelig', 'hijgerig', 'huwelijks', 'accurater', 'pessimistisch', 'planmatig', 'nomadisch', 'uitsluiten', 'promotioneel', 'onderontwikkeld', 'belabberd', 'kameleontisch', 'dapperd', 'bijpassen', 'karikaturaal', 'witt', 'alcoholhoudend', 'prijzen', 'eigengemaakt', 'kollektief', 'rechtzinnig', 'bredere', 'woe', 'fijnbesnaaren', 'traeg', 'hectisch', 'familiair', 'lucratief', 'antikapitalistisch', 'pathologisch', 'gallisch', 'goudblond', 'williger', 'mur ...
# Total unique adjectives: 2938
# Total missing words: 586
# Sample missing words: ['wilsonbekwame', 'polygaum', 'wereldwijaz', 'grooot', 'wereldwijze', 'wilsonbekwaam', 'droogkomisch', 'maatschappijkritisch', 'ongrondwettig', 'onalledaags']
# Remaining adjectives after final filtering: 2335

# %%
def cosine_similarity(v1: np.ndarray, v2: np.ndarray) -> float:
    return np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2))

def compute_association(w: np.ndarray, A: np.ndarray) -> float:
    return np.mean([cosine_similarity(w, a) for a in A])

def compute_attribute_association(X: np.ndarray, A: np.ndarray) -> np.ndarray:
    return np.array([compute_association(x, A) for x in X])

def compute_attribute_association_L2(A: np.ndarray, T: np.ndarray) -> np.ndarray:
    return np.array([compute_association(a, T) for a in A])

def compute_joint_std(X_Associations: np.ndarray, Y_Associations: np.ndarray) -> float:
    return np.std(np.concatenate([X_Associations, Y_Associations]), ddof=1)

def compute_p_value(X_Diff: np.ndarray, Y_Diff: np.ndarray, permutations: int=1000) -> float:
    test_statistic = np.sum(X_Diff) - np.sum(Y_Diff)
    empirical_distribution = np.array([np.random.choice(np.concatenate([X_Diff, Y_Diff]), size=len(X_Diff) + len(Y_Diff), replace=False) for _ in range(permutations)])
    empirical_differences = np.sum(empirical_distribution[:, :len(X_Diff)], axis=1) - np.sum(empirical_distribution[:, len(X_Diff):], axis=1)
    
    return 1-norm.cdf(test_statistic, loc=np.mean(empirical_differences), scale=np.std(empirical_differences, ddof=1))

def level_1(X: np.ndarray, Y: np.ndarray, A: np.ndarray, B: np.ndarray, permutations: int=1000) -> float:
    X_Associations_A = compute_attribute_association(X, A)
    X_Associations_B = compute_attribute_association(X, B)
    X_Differential_Associations = X_Associations_A - X_Associations_B

    Y_Associations_A = compute_attribute_association(Y, A)
    Y_Associations_B = compute_attribute_association(Y, B)
    Y_Differential_Associations = Y_Associations_A - Y_Associations_B

    X_Mean = np.mean(X_Differential_Associations)
    Y_Mean = np.mean(Y_Differential_Associations)

    p_value = compute_p_value(X_Differential_Associations, Y_Differential_Associations, permutations=permutations)

    return (X_Mean - Y_Mean) / compute_joint_std(X_Differential_Associations, Y_Differential_Associations), p_value

def level_2(T: np.ndarray, A: np.ndarray, B: np.ndarray, permutations: int=1000) -> float:
    A_Associations_T = compute_attribute_association_L2(A, T)
    B_Associations_T = compute_attribute_association_L2(B, T)

    p_value = compute_p_value(A_Associations_T, B_Associations_T, permutations=permutations)

    return (np.mean(A_Associations_T) - np.mean(B_Associations_T)) / compute_joint_std(A_Associations_T, B_Associations_T), p_value

def level_3(T: np.ndarray, A: np.ndarray) -> float:
    T_Associations_A = [cosine_similarity(t, a) for t in T for a in A]
    return np.mean(T_Associations_A), np.std(T_Associations_A, ddof=1)

def ML_EAT(A: np.ndarray, B: np.ndarray, X: np.ndarray, Y: np.ndarray, permutations: int=1000) -> dict:
    L1_effect_size, L1_p_value = level_1(X, Y, A, B, permutations=permutations)
    L2_effect_size_X, L2_p_value_X = level_2(X, A, B, permutations=permutations)
    L2_effect_size_Y, L2_p_value_Y = level_2(Y, A, B, permutations=permutations)
    L3_mean_AX, L3_std_AX = level_3(X, A)
    L3_mean_BX, L3_std_BX = level_3(X, B)
    L3_mean_AY, L3_std_AY = level_3(Y, A)
    L3_mean_BY, L3_std_BY = level_3(Y, B)

    return {
        'L1_effect_size': L1_effect_size,
        'L1_p_value': L1_p_value,
        'L2_effect_size_X': L2_effect_size_X,
        'L2_p_value_X': L2_p_value_X,
        'L2_effect_size_Y': L2_effect_size_Y,
        'L2_p_value_Y': L2_p_value_Y,
        'L3_mean_AX': L3_mean_AX,
        'L3_std_AX': L3_std_AX,
        'L3_mean_BX': L3_mean_BX,
        'L3_std_BX': L3_std_BX,
        'L3_mean_AY': L3_mean_AY,
        'L3_std_AY': L3_std_AY,
        'L3_mean_BY': L3_mean_BY,
        'L3_std_BY': L3_std_BY,
    }
def get_np_embeddings(target_words: list,
                      vocab_dict: dict,
                      embeddings: np.ndarray) -> np.ndarray:
    """
    Get the embeddings for the target words.
    """

    return np.array([embeddings[vocab_dict[word]] for word in target_words])

# %%
MALE_WORDS = [
    "man", "kerel", "jongen", "vader", "zoon", "vent", "gast", "meneer", "opa", "oom"
]
FEMALE_WORDS = [
    "vrouw", "dame", "meisje", "moeder", "dochter", "tante", "oma", "mevrouw", "meid"
]

# %%
def compute_individual_bias(
    adjectives,
    male_terms,
    female_terms,
    model,
    exclude_substrings=True
):

    if exclude_substrings:
        all_target_words = set(male_terms + female_terms)
        def has_target_substring(adj):
            return any(tw in adj for tw in all_target_words)
        adjectives = [adj for adj in adjectives if not has_target_substring(adj)]
    print(f"Aantal overgebleven adjectives na substring-filter: {len(adjectives)}")

    records = []

    for adj in adjectives:
        if adj not in model:
            print(f"'{adj}' niet in model — overslaan")
            continue

        adj_vec = model[adj]
        male_sims = [cosine_similarity(adj_vec, model[m]) for m in male_terms if m in model]
        female_sims = [cosine_similarity(adj_vec, model[f]) for f in female_terms if f in model]

        if len(male_sims) == 0 or len(female_sims) == 0:
            print(f"Onvoldoende vergelijkbare woorden voor '{adj}' — overslaan")
            continue

        male_mean = np.mean(male_sims)
        female_mean = np.mean(female_sims)
        bias_value = male_mean - female_mean

        print(f"'{adj}': bias = {bias_value:.4f}")
        records.append({
            "word": adj,
            "male_mean": male_mean,
            "female_mean": female_mean,
            "bias_value": bias_value
        })

    df_bias = pd.DataFrame(records)
    print(f"Totaal aantal berekende bias-waarden: {len(df_bias)}")
    return df_bias


individual_bias = compute_individual_bias(adjectives=filtered_adjectives, male_terms=MALE_WORDS, female_terms=FEMALE_WORDS, model=nl_model)
print(f"Totaal aantal berekende bias-waarden: {len(individual_bias)}")
    
    # Sorteer oplopend op 'bias_value'
df_sorted = individual_bias.sort_values("bias_value", ascending=True)

    # Selecteer de 30 laagste scores
lowest_30 = df_sorted.head(30)

    # Selecteer de 30 hoogste scores
highest_30 = df_sorted.tail(30)

print("=== 30 Laagste Scores (bias_value) ===")
for _, row in lowest_30.iterrows():
    print(f"{row['word']}: {row['bias_value']:.4f} "
            f"(male_mean={row['male_mean']:.4f}, female_mean={row['female_mean']:.4f})")

print("\n=== 30 Hoogste Scores (bias_value) ===")
for _, row in highest_30.iloc[::-1].iterrows():
    print(f"{row['word']}: {row['bias_value']:.4f} "
        f"(male_mean={row['male_mean']:.4f}, female_mean={row['female_mean']:.4f})")
    
df_sorted_male = individual_bias.sort_values("male_mean", ascending=False)
top_30_male_mean = df_sorted_male.head(30)

print("\n=== 30 Hoogste male_mean (onafhankelijk van female_mean) ===")
for _, row in top_30_male_mean.iterrows():
    print(f"{row['word']} - male_mean={row['male_mean']:.4f}, "
          f"female_mean={row['female_mean']:.4f}, bias={row['bias_value']:.4f}")

# En idem voor female_mean
df_sorted_female = individual_bias.sort_values("female_mean", ascending=False)
top_30_female_mean = df_sorted_female.head(30)

print("\n=== 30 Hoogste female_mean (onafhankelijk van male_mean) ===")
for _, row in top_30_female_mean.iterrows():
    print(f"{row['word']} - female_mean={row['female_mean']:.4f}, "
          f"male_mean={row['male_mean']:.4f}, bias={row['bias_value']:.4f}")
# Out:
# Aantal overgebleven adjectives na substring-filter: 2335
# 'groot' niet in model — overslaan
# 'vreemd' niet in model — overslaan
# 'prachtig' niet in model — overslaan
# 'onschuldig' niet in model — overslaan
# 'angstig' niet in model — overslaan
# 'koppig' niet in model — overslaan
# 'uitzonderlijk' niet in model — overslaan
# 'verkiesbaar' niet in model — overslaan
# 'ongerust' niet in model — overslaan
# 'praatgraag' niet in model — overslaan
# 'teder' niet in model — overslaan
# 'grof' niet in model — overslaan
# 'schimmig' niet in model — overslaan
# 'polygame' niet in model — overslaan
# 'onvriendelijk' niet in model — overslaan
# 'wantrouwen' niet in model — overslaan
# 'vervaarlijk' niet in model — overslaan
# 'eervol' niet in model — overslaan
# 'onsterfelijk' niet in model — overslaan
# 'snobistisch' niet in model — overslaan
# 'heimelijk' niet in model — overslaan
# 'atypisch' niet in model — overslaan
# 'wantrouwend' niet in model — overslaan
# 'tegenstrijdig' niet in model — overslaan
# 'rafelig' niet in model — overslaan
# 'wereldwijs' niet in model — overslaan
# 'polygaam' niet in model — overslaan
# 'nadenken' niet in model — overslaan
# 'panisch' niet in model — overslaan
# 'onbestemd' niet in model — overslaan
# 'eindig' niet in model — overslaan
# 'onzelfzuchtig' niet in model — overslaan
# 'diepzinnig' niet in model — overslaan
# 'vreemder' niet in model — overslaan
# 'hondsbrutaal' niet in model — overslaan
# 'etherisch' niet in model — overslaan
# 'prinselijk' niet in model — overslaan
# 'extern' niet in model — overslaan
# 'onwerkelijk' niet in model — overslaan
# 'wisselvallig' niet in model — overslaan
# 'tumultueus' niet in model — overslaan
# 'levenskrachtig' niet in model — overslaan
# 'stemmig' niet in model — overslaan
# 'geelgroen' niet in model — overslaan
# 'grover' niet in model — overslaan
# 'gortdroog' niet in model — overslaan
# 'zuidwaarts' niet in model — overslaan
# 'geestelijk' niet in model — overslaan
# 'afwezig' niet in model — overslaan
# 'gemiddeld' niet in model — overslaan
# 'streng' niet in model — overslaan
# 'louter' niet in model — overslaan
# 'katholiek' niet in model — overslaan
# 'rechts' niet in model — overslaan
# 'servisch' niet in model — overslaan
# 'specifiek' niet in model — overslaan
# 'enorm' niet in model — overslaan
# 'gematigd' niet in model — overslaan
# 'ruig' niet in model — overslaan
# 'kleurloos' niet in model — overslaan
# 'zwartharig' niet in model — overslaan
# 'orthodox' niet in model — overslaan
# 'diepgelovig' niet in model — overslaan
# 'bozig' niet in model — overslaan
# 'formeel' niet in model — overslaan
# 'oppermachtig' niet in model — overslaan
# 'straatarm' niet in model — overslaan
# 'alleenstaand' niet in model — overslaan
# 'psychiatrisch' niet in model — overslaan
# 'bomvol' niet in model — overslaan
# 'gloednieuw' niet in model — overslaan
# 'slordig' niet in model — overslaan
# 'mistroostig' niet in model — overslaan
# 'finaal' niet in model — overslaan
# 'afstotelijk' niet in model — overslaan
# 'tactisch' niet in model — overslaan
# 'grofgebekt' niet in model — overslaan
# 'milieubewust' niet in model — overslaan
# 'ellendig' niet in model — overslaan
# 'slappe' niet in model — overslaan
# 'kien' niet in model — overslaan
# 'vinnig' niet in model — overslaan
# 'impopulair' niet in model — overslaan
# 'slapper' niet in model — overslaan
# 'ruiger' niet in model — overslaan
# 'slap' niet in model — overslaan
# 'omzichtig' niet in model — overslaan
# 'chemisch' niet in model — overslaan
# 'opportuun' niet in model — overslaan
# 'schutterig' niet in model — overslaan
# 'bloedig' niet in model — overslaan
# 'toonbaar' niet in model — overslaan
# 'gematigder' niet in model — overslaan
# 'aartslelijk' niet in model — overslaan
# 'lauw' niet in model — overslaan
# 'plaatsvervangend' niet in model — overslaan
# 'onverenigbaar' niet in model — overslaan
# 'onvolledig' niet in model — overslaan
# 'geestelijke' niet in model — overslaan
# 'sereen' niet in model — overslaan
# 'behaaglijk' niet in model — overslaan
# 'pregnant' niet in model — overslaan
# 'wit' niet in model — overslaan
# 'bijzonder' niet in model — overslaan
# 'slim' niet in model — overslaan
# 'uitsluitend' niet in model — overslaan
# 'gewelddadig' niet in model — overslaan
# 'vrolijk' niet in model — overslaan
# 'lastig' niet in model — overslaan
# 'vermogend' niet in model — overslaan
# 'inheems' niet in model — overslaan
# 'aanwezig' niet in model — overslaan
# 'stevig' niet in model — overslaan
# 'commercieel' niet in model — overslaan
# 'dapper' niet in model — overslaan
# 'anoniem' niet in model — overslaan
# 'volledig' niet in model — overslaan
# 'serieus' niet in model — overslaan
# 'internationaal' niet in model — overslaan
# 'breed' niet in model — overslaan
# 'naamloos' niet in model — overslaan
# 'individueel' niet in model — overslaan
# 'progressief' niet in model — overslaan
# 'mollig' niet in model — overslaan
# 'indrukwekkend' niet in model — overslaan
# 'pittig' niet in model — overslaan
# 'religieus' niet in model — overslaan
# 'begaafd' niet in model — overslaan
# 'onecht' niet in model — overslaan
# 'wereldvreemd' niet in model — overslaan
# 'opmerkelijk' niet in model — overslaan
# 'olympisch' niet in model — overslaan
# 'absoluut' niet in model — overslaan
# 'volwaardig' niet in model — overslaan
# 'driftig' niet in model — overslaan
# 'kundig' niet in model — overslaan
# 'maximaal' niet in model — overslaan
# 'plezierig' niet in model — overslaan
# 'willig' niet in model — overslaan
# 'dominicaans' niet in model — overslaan
# 'constant' niet in model — overslaan
# 'seksistisch' niet in model — overslaan
# 'literair' niet in model — overslaan
# 'woest' niet in model — overslaan
# 'lieftallig' niet in model — overslaan
# 'dierbaar' niet in model — overslaan
# 'mentaal' niet in model — overslaan
# 'oostwaarts' niet in model — overslaan
# 'corrupt' niet in model — overslaan
# 'luidkeels' niet in model — overslaan
# 'onwillig' niet in model — overslaan
# 'instabiel' niet in model — overslaan
# 'onmiskenbaar' niet in model — overslaan
# 'gedeeltelijk' niet in model — overslaan
# 'ongelovig' niet in model — overslaan
# 'vurig' niet in model — overslaan
# 'studentikoos' niet in model — overslaan
# 'dol' niet in model — overslaan
# 'traag' niet in model — overslaan
# 'verbazingwekkend' niet in model — overslaan
# 'collectief' niet in model — overslaan
# 'alert' niet in model — overslaan
# 'engelstalig' niet in model — overslaan
# 'wilsbekwaam' niet in model — overslaan
# 'eenarmig' niet in model — overslaan
# 'missen' niet in model — overslaan
# 'wezenloos' niet in model — overslaan
# 'present' niet in model — overslaan
# 'paniekerig' niet in model — overslaan
# 'kunstzinnig' niet in model — overslaan
# 'goddeloos' niet in model — overslaan
# 'schaamteloos' niet in model — overslaan
# 'lastigst' niet in model — overslaan
# 'grootstedelijk' niet in model — overslaan
# 'dof' niet in model — overslaan
# 'godsdienstig' niet in model — overslaan
# 'incidenteel' niet in model — overslaan
# 'minutieus' niet in model — overslaan
# 'mis' niet in model — overslaan
# 'happig' niet in model — overslaan
# 'gehavend' niet in model — overslaan
# 'gelijkmatig' niet in model — overslaan
# 'stug' niet in model — overslaan
# 'nauwkeurig' niet in model — overslaan
# 'gelukzalig' niet in model — overslaan
# 'vijandig' niet in model — overslaan
# 'blits' niet in model — overslaan
# 'onbenullig' niet in model — overslaan
# 'onrechtvaardig' niet in model — overslaan
# 'lieflijk' niet in model — overslaan
# 'onbeschermd' niet in model — overslaan
# 'onveranderd' niet in model — overslaan
# 'elektronisch' niet in model — overslaan
# 'evangelisch' niet in model — overslaan
# 'parlementair' niet in model — overslaan
# 'cognitief' niet in model — overslaan
# 'priesterlijk' niet in model — overslaan
# 'attractief' niet in model — overslaan
# 'flinterdun' niet in model — overslaan
# 'zinvol' niet in model — overslaan
# 'kortademig' niet in model — overslaan
# 'evident' niet in model — overslaan
# 'verzot' niet in model — overslaan
# 'benard' niet in model — overslaan
# 'directief' niet in model — overslaan
# 'afkerig' niet in model — overslaan
# 'ongelijksoortig' niet in model — overslaan
# 'laks' niet in model — overslaan
# 'goor' niet in model — overslaan
# 'eerloos' niet in model — overslaan
# 'gitzwart' niet in model — overslaan
# 'vulkanisch' niet in model — overslaan
# 'onverhoeds' niet in model — overslaan
# 'duizelig' niet in model — overslaan
# 'pessimistisch' niet in model — overslaan
# 'planmatig' niet in model — overslaan
# 'uitsluiten' niet in model — overslaan
# 'onderontwikkeld' niet in model — overslaan
# 'belabberd' niet in model — overslaan
# 'kameleontisch' niet in model — overslaan
# 'bijpassen' niet in model — overslaan
# 'karikaturaal' niet in model — overslaan
# 'alcoholhoudend' niet in model — overslaan
# 'prijzen' niet in model — overslaan
# 'eigengemaakt' niet in model — overslaan
# 'rechtzinnig' niet in model — overslaan
# 'bredere' niet in model — overslaan
# 'woe' niet in model — overslaan
# 'familiair' niet in model — overslaan
# 'lucratief' niet in model — overslaan
# 'pathologisch' niet in model — overslaan
# 'gallisch' niet in model — overslaan
# 'goudblond' niet in model — overslaan
# 'murw' niet in model — overslaan
# 'genoegzaam' niet in model — overslaan
# 'filantropisch' niet in model — overslaan
# 'demissionair' niet in model — overslaan
# 'accuraat' niet in model — overslaan
# 'onvergankelijk' niet in model — overslaan
# 'stevigst' niet in model — overslaan
# 'geolied' niet in model — overslaan
# 'lieflijker' niet in model — overslaan
# 'bevederd' niet in model — overslaan
# 'buitenkerkelijk' niet in model — overslaan
# 'glorierijk' niet in model — overslaan
# 'financieel' niet in model — overslaan
# 'vrij' niet in model — overslaan
# 'amerikaans' niet in model — overslaan
# 'ideaal' niet in model — overslaan
# 'intelligent' niet in model — overslaan
# 'overspelig' niet in model — overslaan
# 'gelukkig' niet in model — overslaan
# 'keurig' niet in model — overslaan
# 'zweeds' niet in model — overslaan
# 'tegenwoordig' niet in model — overslaan
# 'charismatisch' niet in model — overslaan
# 'stil' niet in model — overslaan
# 'geschikt' niet in model — overslaan
# 'vermoedelijk' niet in model — overslaan
# 'zweedse' niet in model — overslaan
# 'moedig' niet in model — overslaan
# 'australisch' niet in model — overslaan
# 'hysterisch' niet in model — overslaan
# 'koreaans' niet in model — overslaan
# 'emotioneel' niet in model — overslaan
# 'tweejarig' niet in model — overslaan
# 'zielig' niet in model — overslaan
# 'beminnelijk' niet in model — overslaan
# 'elegant' niet in model — overslaan
# 'populair' niet in model — overslaan
# 'stokoud' niet in model — overslaan
# 'gelijkwaardig' niet in model — overslaan
# 'lekker' niet in model — overslaan
# 'bereid' niet in model — overslaan
# 'daadwerkelijk' niet in model — overslaan
# 'simpel' niet in model — overslaan
# 'wakker' niet in model — overslaan
# 'systematisch' niet in model — overslaan
# 'wettelijk' niet in model — overslaan
# 'slungelig' niet in model — overslaan
# 'redelijk' niet in model — overslaan
# 'raadselachtig' niet in model — overslaan
# 'bloedmooi' niet in model — overslaan
# 'kil' niet in model — overslaan
# 'totaal' niet in model — overslaan
# 'fit' niet in model — overslaan
# 'geestesziek' niet in model — overslaan
# 'geduldig' niet in model — overslaan
# 'nukkig' niet in model — overslaan
# 'irritant' niet in model — overslaan
# 'toevallig' niet in model — overslaan
# 'momenteel' niet in model — overslaan
# 'gezamenlijk' niet in model — overslaan
# 'respectabel' niet in model — overslaan
# 'hoffelijk' niet in model — overslaan
# 'leergierig' niet in model — overslaan
# 'strikt' niet in model — overslaan
# 'vanzelfsprekend' niet in model — overslaan
# 'aandoenlijk' niet in model — overslaan
# 'bedeesd' niet in model — overslaan
# 'koreaanse' niet in model — overslaan
# 'extreem' niet in model — overslaan
# 'humeurig' niet in model — overslaan
# 'langdurig' niet in model — overslaan
# 'volgzaam' niet in model — overslaan
# 'engelachtig' niet in model — overslaan
# 'spastisch' niet in model — overslaan
# 'hoekig' niet in model — overslaan
# 'slonzig' niet in model — overslaan
# 'triest' niet in model — overslaan
# 'rauw' niet in model — overslaan
# 'krankzinnig' niet in model — overslaan
# 'onrustig' niet in model — overslaan
# 'bereiden' niet in model — overslaan
# 'giftig' niet in model — overslaan
# 'curieus' niet in model — overslaan
# 'demonstratief' niet in model — overslaan
# 'klunzig' niet in model — overslaan
# 'intiem' niet in model — overslaan
# 'ruimdenkend' niet in model — overslaan
# 'intelligentst' niet in model — overslaan
# 'onaantastbaar' niet in model — overslaan
# 'laveloos' niet in model — overslaan
# 'goedhartig' niet in model — overslaan
# 'bars' niet in model — overslaan
# 'controversieel' niet in model — overslaan
# 'grimmig' niet in model — overslaan
# 'koninklijk' niet in model — overslaan
# 'onbevreesd' niet in model — overslaan
# 'aaibare' niet in model — overslaan
# 'pijnlijk' niet in model — overslaan
# 'waanzinnig' niet in model — overslaan
# 'culinair' niet in model — overslaan
# 'droog' niet in model — overslaan
# 'grondig' niet in model — overslaan
# 'oerlelijk' niet in model — overslaan
# 'tijdig' niet in model — overslaan
# 'ultieme' niet in model — overslaan
# 'ijzig' niet in model — overslaan
# 'achteloos' niet in model — overslaan
# 'onwennig' niet in model — overslaan
# 'gedienstig' niet in model — overslaan
# 'productief' niet in model — overslaan
# 'volcontinu' niet in model — overslaan
# 'vakkundig' niet in model — overslaan
# 'wantrouwig' niet in model — overslaan
# 'onbenut' niet in model — overslaan
# 'paars' niet in model — overslaan
# 'keltisch' niet in model — overslaan
# 'nadelig' niet in model — overslaan
# 'sussen' niet in model — overslaan
# 'eensgezind' niet in model — overslaan
# 'laagdrempelig' niet in model — overslaan
# 'onopmerkelijk' niet in model — overslaan
# 'grandioos' niet in model — overslaan
# 'betaalbaar' niet in model — overslaan
# 'onvoorzichtig' niet in model — overslaan
# 'succesrijk' niet in model — overslaan
# 'ongebruikelijk' niet in model — overslaan
# 'roekeloos' niet in model — overslaan
# 'emotieloos' niet in model — overslaan
# 'scheef' niet in model — overslaan
# 'oudtestamentisch' niet in model — overslaan
# 'feilbaar' niet in model — overslaan
# 'kosmopolitisch' niet in model — overslaan
# 'poeslief' niet in model — overslaan
# 'stroef' niet in model — overslaan
# 'vijandelijk' niet in model — overslaan
# 'oneindig' niet in model — overslaan
# 'bruut' niet in model — overslaan
# 'ambivalent' niet in model — overslaan
# 'doelloos' niet in model — overslaan
# 'zinnig' niet in model — overslaan
# 'stijve' niet in model — overslaan
# 'liederlijk' niet in model — overslaan
# 'ogenblikkelijk' niet in model — overslaan
# 'zaterdags' niet in model — overslaan
# 'paradijselijk' niet in model — overslaan
# 'krakkemikkig' niet in model — overslaan
# 'stijf' niet in model — overslaan
# 'pedagogisch' niet in model — overslaan
# 'schadeloos' niet in model — overslaan
# 'geschiktste' niet in model — overslaan
# 'onbeschaafd' niet in model — overslaan
# 'dolblij' niet in model — overslaan
# 'leugenachtig' niet in model — overslaan
# 'ultiem' niet in model — overslaan
# 'feestelijk' niet in model — overslaan
# 'onverdraaglijk' niet in model — overslaan
# 'punctueel' niet in model — overslaan
# 'zedelijk' niet in model — overslaan
# 'oorlogszuchtig' niet in model — overslaan
# 'zonnig' niet in model — overslaan
# 'armoedig' niet in model — overslaan
# 'natuurwetenschappelijk' niet in model — overslaan
# 'omgekeerd' niet in model — overslaan
# 'staatkundig' niet in model — overslaan
# 'vlekkeloos' niet in model — overslaan
# 'riskant' niet in model — overslaan
# 'grenzeloos' niet in model — overslaan
# 'ondubbelzinnig' niet in model — overslaan
# 'populairdere' niet in model — overslaan
# 'intiemer' niet in model — overslaan
# 'mensachtig' niet in model — overslaan
# 'onvast' niet in model — overslaan
# 'onversaagd' niet in model — overslaan
# 'eminent' niet in model — overslaan
# 'industrieel' niet in model — overslaan
# 'excessief' niet in model — overslaan
# 'slinks' niet in model — overslaan
# 'unaniem' niet in model — overslaan
# 'tweeledig' niet in model — overslaan
# 'haarscherp' niet in model — overslaan
# 'vrijpostig' niet in model — overslaan
# 'delicaat' niet in model — overslaan
# 'ontegenzeggelijk' niet in model — overslaan
# 'hoogbejaard' niet in model — overslaan
# 'beschaamd' niet in model — overslaan
# 'ingeburgerd' niet in model — overslaan
# 'antiek' niet in model — overslaan
# 'kleinschalig' niet in model — overslaan
# 'kattig' niet in model — overslaan
# 'horig' niet in model — overslaan
# 'futuristisch' niet in model — overslaan
# 'conflictueus' niet in model — overslaan
# 'euforisch' niet in model — overslaan
# 'overzichtelijk' niet in model — overslaan
# 'omgekeerde' niet in model — overslaan
# 'balsturig' niet in model — overslaan
# 'pornografisch' niet in model — overslaan
# 'bewegelijk' niet in model — overslaan
# 'nipt' niet in model — overslaan
# 'eenstemmig' niet in model — overslaan
# 'secundair' niet in model — overslaan
# 'toepasselijk' niet in model — overslaan
# 'oerdegelijk' niet in model — overslaan
# 'bitsig' niet in model — overslaan
# 'onmetelijk' niet in model — overslaan
# 'landerig' niet in model — overslaan
# 'onverzadigd' niet in model — overslaan
# 'amerikaanser' niet in model — overslaan
# 'knettergek' niet in model — overslaan
# 'onhoudbaar' niet in model — overslaan
# 'onkundig' niet in model — overslaan
# 'filmisch' niet in model — overslaan
# 'eigenmachtig' niet in model — overslaan
# 'motorisch' niet in model — overslaan
# 'kopschuw' niet in model — overslaan
# 'onsportief' niet in model — overslaan
# 'genoeglijk' niet in model — overslaan
# 'grondwettelijk' niet in model — overslaan
# 'gemelijk' niet in model — overslaan
# 'avondlijk' niet in model — overslaan
# 'huilerig' niet in model — overslaan
# 'naarstig' niet in model — overslaan
# 'onwerkbaar' niet in model — overslaan
# 'dik' niet in model — overslaan
# 'modern' niet in model — overslaan
# 'vieze' niet in model — overslaan
# 'fataal' niet in model — overslaan
# 'ambitieus' niet in model — overslaan
# 'onderling' niet in model — overslaan
# 'fors' niet in model — overslaan
# 'ernstig' niet in model — overslaan
# 'interessant' niet in model — overslaan
# 'fantastisch' niet in model — overslaan
# 'gezellig' niet in model — overslaan
# 'veelzijdig' niet in model — overslaan
# 'halfnaakt' niet in model — overslaan
# 'makkelijk' niet in model — overslaan
# 'zacht' niet in model — overslaan
# 'flink' niet in model — overslaan
# 'verschrikkelijk' niet in model — overslaan
# 'inclusief' niet in model — overslaan
# 'beschikbaar' niet in model — overslaan
# 'pervers' niet in model — overslaan
# 'imposant' niet in model — overslaan
# 'sullig' niet in model — overslaan
# 'willekeurig' niet in model — overslaan
# 'pezig' niet in model — overslaan
# 'creatief' niet in model — overslaan
# 'onmogelijk' niet in model — overslaan
# 'middelmatig' niet in model — overslaan
# 'etnisch' niet in model — overslaan
# 'druk' niet in model — overslaan
# 'levendig' niet in model — overslaan
# 'onaantrekkelijk' niet in model — overslaan
# 'anglicaans' niet in model — overslaan
# 'persoonlijk' niet in model — overslaan
# 'optimistisch' niet in model — overslaan
# 'gemene' niet in model — overslaan
# 'ijdel' niet in model — overslaan
# 'sentimenteel' niet in model — overslaan
# 'passief' niet in model — overslaan
# 'zondig' niet in model — overslaan
# 'walgelijk' niet in model — overslaan
# 'wild' niet in model — overslaan
# 'vers' niet in model — overslaan
# 'ongeneeslijk' niet in model — overslaan
# 'ongewenst' niet in model — overslaan
# 'nadrukkelijk' niet in model — overslaan
# 'onverschillig' niet in model — overslaan
# 'origineel' niet in model — overslaan
# 'activistisch' niet in model — overslaan
# 'grillig' niet in model — overslaan
# 'universitair' niet in model — overslaan
# 'heldhaftig' niet in model — overslaan
# 'monddood' niet in model — overslaan
# 'breedsprakig' niet in model — overslaan
# 'vies' niet in model — overslaan
# 'loyaal' niet in model — overslaan
# 'dikkere' niet in model — overslaan
# 'roerloos' niet in model — overslaan
# 'beduidend' niet in model — overslaan
# 'bestaand' niet in model — overslaan
# 'vlezig' niet in model — overslaan
# 'kranig' niet in model — overslaan
# 'denkbeeldig' niet in model — overslaan
# 'hopeloos' niet in model — overslaan
# 'overduidelijk' niet in model — overslaan
# 'afzonderlijk' niet in model — overslaan
# 'grauw' niet in model — overslaan
# 'koud' niet in model — overslaan
# 'huiverig' niet in model — overslaan
# 'hulpvaardig' niet in model — overslaan
# 'dusdanig' niet in model — overslaan
# 'nederig' niet in model — overslaan
# 'problematisch' niet in model — overslaan
# 'monumentaal' niet in model — overslaan
# 'gruwelijk' niet in model — overslaan
# 'incestueus' niet in model — overslaan
# 'onverslaanbaar' niet in model — overslaan
# 'smerig' niet in model — overslaan
# 'overbelast' niet in model — overslaan
# 'tegendraads' niet in model — overslaan
# 'flexibel' niet in model — overslaan
# 'nat' niet in model — overslaan
# 'makkelijkst' niet in model — overslaan
# 'ongedaan' niet in model — overslaan
# 'ondervoed' niet in model — overslaan
# 'weemoedig' niet in model — overslaan
# 'onbeduidend' niet in model — overslaan
# 'nonchalant' niet in model — overslaan
# 'vaardig' niet in model — overslaan
# 'bijgelovig' niet in model — overslaan
# 'studieus' niet in model — overslaan
# 'boeiend' niet in model — overslaan
# 'suffe' niet in model — overslaan
# 'toerekeningsvatbaar' niet in model — overslaan
# 'objectief' niet in model — overslaan
# 'bangig' niet in model — overslaan
# 'helder' niet in model — overslaan
# 'dierlijk' niet in model — overslaan
# 'smakelijk' niet in model — overslaan
# 'ploertig' niet in model — overslaan
# 'wenselijk' niet in model — overslaan
# 'pikzwart' niet in model — overslaan
# 'onverstaanbaar' niet in model — overslaan
# 'wrokkig' niet in model — overslaan
# 'experimenteel' niet in model — overslaan
# 'bikkelhard' niet in model — overslaan
# 'buigzaam' niet in model — overslaan
# 'bijdetijds' niet in model — overslaan
# 'ordeloos' niet in model — overslaan
# 'onopgemerkt' niet in model — overslaan
# 'naadloos' niet in model — overslaan
# 'spaarzaam' niet in model — overslaan
# 'geestrijk' niet in model — overslaan
# 'hinderlijk' niet in model — overslaan
# 'wrang' niet in model — overslaan
# 'onbeschaamd' niet in model — overslaan
# 'vlinderachtig' niet in model — overslaan
# 'appetijtelijk' niet in model — overslaan
# 'zachter' niet in model — overslaan
# 'haalbaar' niet in model — overslaan
# 'patriottisch' niet in model — overslaan
# 'individualistisch' niet in model — overslaan
# 'gemeen' niet in model — overslaan
# 'plooibaar' niet in model — overslaan
# 'broeierig' niet in model — overslaan
# 'langdradig' niet in model — overslaan
# 'kouw' niet in model — overslaan
# 'ongeoorloofd' niet in model — overslaan
# 'verkleed' niet in model — overslaan
# 'krap' niet in model — overslaan
# 'grijzig' niet in model — overslaan
# 'eloquent' niet in model — overslaan
# 'pretentieloos' niet in model — overslaan
# 'twijfelachtig' niet in model — overslaan
# 'pijlsnel' niet in model — overslaan
# 'kortzichtig' niet in model — overslaan
# 'onvervaard' niet in model — overslaan
# 'schandalig' niet in model — overslaan
# 'sedentair' niet in model — overslaan
# 'periodiek' niet in model — overslaan
# 'inwisselbaar' niet in model — overslaan
# 'onzinnig' niet in model — overslaan
# 'bemoedigend' niet in model — overslaan
# 'synthetisch' niet in model — overslaan
# 'dweperig' niet in model — overslaan
# 'ordelijk' niet in model — overslaan
# 'onnatuurlijk' niet in model — overslaan
# 'onhaalbaar' niet in model — overslaan
# 'schadelijk' niet in model — overslaan
# 'nieuwtestamentisch' niet in model — overslaan
# 'deemoedig' niet in model — overslaan
# 'ongegrond' niet in model — overslaan
# 'barok' niet in model — overslaan
# 'flinke' niet in model — overslaan
# 'zoetig' niet in model — overslaan
# 'voos' niet in model — overslaan
# 'koortsig' niet in model — overslaan
# 'benig' niet in model — overslaan
# 'lijzig' niet in model — overslaan
# 'aardig' niet in model — overslaan
# 'zwaar' niet in model — overslaan
# 'naakt' niet in model — overslaan
# 'lesbisch' niet in model — overslaan
# 'gehandicapt' niet in model — overslaan
# 'eng' niet in model — overslaan
# 'aimabel' niet in model — overslaan
# 'zwaargewond' niet in model — overslaan
# 'zelfbewust' niet in model — overslaan
# 'fatsoenlijk' niet in model — overslaan
# 'buitenechtelijk' niet in model — overslaan
# 'zwijgzaam' niet in model — overslaan
# 'alcoholisch' niet in model — overslaan
# 'nuchter' niet in model — overslaan
# 'conservatief' niet in model — overslaan
# 'doof' niet in model — overslaan
# 'briljant' niet in model — overslaan
# 'dove' niet in model — overslaan
# 'bedachtzaam' niet in model — overslaan
# 'juridisch' niet in model — overslaan
# 'zwakbegaafd' niet in model — overslaan
# 'breekbaar' niet in model — overslaan
# 'voortvluchtig' niet in model — overslaan
# 'deskundig' niet in model — overslaan
# 'behulpzaam' niet in model — overslaan
# 'tragisch' niet in model — overslaan
# 'aanvankelijk' niet in model — overslaan
# 'los' niet in model — overslaan
# 'mild' niet in model — overslaan
# 'traditioneel' niet in model — overslaan
# 'eigenaardig' niet in model — overslaan
# 'empathisch' niet in model — overslaan
# 'eigenwijs' niet in model — overslaan
# 'volks' niet in model — overslaan
# 'hippe' niet in model — overslaan
# 'dodelijk' niet in model — overslaan
# 'radicaal' niet in model — overslaan
# 'evenwichtig' niet in model — overslaan
# 'seculier' niet in model — overslaan
# 'openlijk' niet in model — overslaan
# 'dwars' niet in model — overslaan
# 'knoestig' niet in model — overslaan
# 'aards' niet in model — overslaan
# 'begeerlijk' niet in model — overslaan
# 'zwaarder' niet in model — overslaan
# 'diep' niet in model — overslaan
# 'mythisch' niet in model — overslaan
# 'eenzelvig' niet in model — overslaan
# 'zenuwachtig' niet in model — overslaan
# 'onweerstaanbaar' niet in model — overslaan
# 'ijzersterk' niet in model — overslaan
# 'professioneel' niet in model — overslaan
# 'zakelijk' niet in model — overslaan
# 'competent' niet in model — overslaan
# 'kwaadaardig' niet in model — overslaan
# 'wekelijks' niet in model — overslaan
# 'spreekwoordelijk' niet in model — overslaan
# 'attent' niet in model — overslaan
# 'liefdeloos' niet in model — overslaan
# 'harig' niet in model — overslaan
# 'waardig' niet in model — overslaan
# 'medisch' niet in model — overslaan
# 'sjiitisch' niet in model — overslaan
# 'melancholisch' niet in model — overslaan
# 'afschuwelijk' niet in model — overslaan
# 'identiek' niet in model — overslaan
# 'onrein' niet in model — overslaan
# 'agrarisch' niet in model — overslaan
# 'hip' niet in model — overslaan
# 'innig' niet in model — overslaan
# 'psychisch' niet in model — overslaan
# 'geloofwaardig' niet in model — overslaan
# 'smal' niet in model — overslaan
# 'schijnbaar' niet in model — overslaan
# 'argeloos' niet in model — overslaan
# 'reformatorisch' niet in model — overslaan
# 'ongelooflijk' niet in model — overslaan
# 'opgelucht' niet in model — overslaan
# 'gracieus' niet in model — overslaan
# 'pokdalig' niet in model — overslaan
# 'bits' niet in model — overslaan
# 'plat' niet in model — overslaan
# 'conservatiever' niet in model — overslaan
# 'korzelig' niet in model — overslaan
# 'genadeloos' niet in model — overslaan
# 'triomfantelijk' niet in model — overslaan
# 'ongevaarlijk' niet in model — overslaan
# 'verdienstelijk' niet in model — overslaan
# 'besluiteloos' niet in model — overslaan
# 'preuts' niet in model — overslaan
# 'waard' niet in model — overslaan
# 'marginaal' niet in model — overslaan
# 'koelbloedig' niet in model — overslaan
# 'losse' niet in model — overslaan
# 'humaan' niet in model — overslaan
# 'getalsmatig' niet in model — overslaan
# 'verwant' niet in model — overslaan
# 'onbeweeglijk' niet in model — overslaan
# 'fragiel' niet in model — overslaan
# 'pontificaal' niet in model — overslaan
# 'ontoegankelijk' niet in model — overslaan
# 'exact' niet in model — overslaan
# 'nauw' niet in model — overslaan
# 'zinloos' niet in model — overslaan
# 'kostelijk' niet in model — overslaan
# 'sleets' niet in model — overslaan
# 'anarchistisch' niet in model — overslaan
# 'onophoudelijk' niet in model — overslaan
# 'proletarisch' niet in model — overslaan
# 'inherent' niet in model — overslaan
# 'ontvlambaar' niet in model — overslaan
# 'onbelangrijk' niet in model — overslaan
# 'gelijktijdig' niet in model — overslaan
# 'lustig' niet in model — overslaan
# 'lawaaierig' niet in model — overslaan
# 'goedgeluimd' niet in model — overslaan
# 'nijdig' niet in model — overslaan
# 'acceptabel' niet in model — overslaan
# 'knullig' niet in model — overslaan
# 'gelijkmoedig' niet in model — overslaan
# 'opmerkzaam' niet in model — overslaan
# 'respectvol' niet in model — overslaan
# 'duitstalig' niet in model — overslaan
# 'misselijk' niet in model — overslaan
# 'comfortabel' niet in model — overslaan
# 'aanbiddelijk' niet in model — overslaan
# 'discreet' niet in model — overslaan
# 'slapeloos' niet in model — overslaan
# 'tijdloos' niet in model — overslaan
# 'incapabel' niet in model — overslaan
# 'vaginaal' niet in model — overslaan
# 'paternalistisch' niet in model — overslaan
# 'gebrekkig' niet in model — overslaan
# 'nodeloos' niet in model — overslaan
# 'multicultureel' niet in model — overslaan
# 'rustiek' niet in model — overslaan
# 'twijfelen' niet in model — overslaan
# 'amoreel' niet in model — overslaan
# 'surrealistisch' niet in model — overslaan
# 'toepasbaar' niet in model — overslaan
# 'eetbaar' niet in model — overslaan
# 'coulant' niet in model — overslaan
# 'bruinig' niet in model — overslaan
# 'bespottelijk' niet in model — overslaan
# 'pips' niet in model — overslaan
# 'buitengerechtelijk' niet in model — overslaan
# 'bestuurlijk' niet in model — overslaan
# 'armzalig' niet in model — overslaan
# 'wazig' niet in model — overslaan
# 'pip' niet in model — overslaan
# 'draagbaar' niet in model — overslaan
# 'rigoureus' niet in model — overslaan
# 'bovenmatig' niet in model — overslaan
# 'voordelig' niet in model — overslaan
# 'katachtig' niet in model — overslaan
# 'immuun' niet in model — overslaan
# 'scheutig' niet in model — overslaan
# 'onverbeterlijk' niet in model — overslaan
# 'onlosmakelijk' niet in model — overslaan
# 'onzedig' niet in model — overslaan
# 'stronteigenwijs' niet in model — overslaan
# 'conformistisch' niet in model — overslaan
# 'rokerig' niet in model — overslaan
# 'veranderlijk' niet in model — overslaan
# 'ongemotiveerd' niet in model — overslaan
# 'overeenkomstig' niet in model — overslaan
# 'uitwendig' niet in model — overslaan
# 'beestachtig' niet in model — overslaan
# 'actueel' niet in model — overslaan
# 'onverdraagzaam' niet in model — overslaan
# 'stokstijf' niet in model — overslaan
# 'hartig' niet in model — overslaan
# 'lamme' niet in model — overslaan
# 'pissig' niet in model — overslaan
# 'vettig' niet in model — overslaan
# 'machtig' niet in model — overslaan
# 'mooi' niet in model — overslaan
# 'blanke' niet in model — overslaan
# 'blank' niet in model — overslaan
# 'verschillend' niet in model — overslaan
# 'onbekend' niet in model — overslaan
# 'braafst' niet in model — overslaan
# 'trots' niet in model — overslaan
# 'dakloos' niet in model — overslaan
# 'surinaams' niet in model — overslaan
# 'autistisch' niet in model — overslaan
# 'kinderloos' niet in model — overslaan
# 'gezond' niet in model — overslaan
# 'achttienjarig' niet in model — overslaan
# 'zorgzaam' niet in model — overslaan
# 'braziliaans' niet in model — overslaan
# 'braaf' niet in model — overslaan
# 'vervelend' niet in model — overslaan
# 'onopvallend' niet in model — overslaan
# 'ouderwets' niet in model — overslaan
# 'ferm' niet in model — overslaan
# 'energiek' niet in model — overslaan
# 'grappig' niet in model — overslaan
# 'surinaamse' niet in model — overslaan
# 'roodharig' niet in model — overslaan
# 'sociaal' niet in model — overslaan
# 'oostenrijks' niet in model — overslaan
# 'opgewekt' niet in model — overslaan
# 'prettig' niet in model — overslaan
# 'werkelijk' niet in model — overslaan
# 'maakbaar' niet in model — overslaan
# 'kennelijk' niet in model — overslaan
# 'humoristisch' niet in model — overslaan
# 'structureel' niet in model — overslaan
# 'excentriek' niet in model — overslaan
# 'voorzichtig' niet in model — overslaan
# 'mysterieus' niet in model — overslaan
# 'achtenswaardig' niet in model — overslaan
# 'blauw' niet in model — overslaan
# 'communistisch' niet in model — overslaan
# 'vooraanstaand' niet in model — overslaan
# 'eenjarig' niet in model — overslaan
# 'rancuneus' niet in model — overslaan
# 'schuin' niet in model — overslaan
# 'baldadig' niet in model — overslaan
# 'geniaal' niet in model — overslaan
# 'rebels' niet in model — overslaan
# 'kroatische' niet in model — overslaan
# 'aangenaam' niet in model — overslaan
# 'definitief' niet in model — overslaan
# 'kroatisch' niet in model — overslaan
# 'bedlegerig' niet in model — overslaan
# 'sluw' niet in model — overslaan
# 'ongevraagd' niet in model — overslaan
# 'brave' niet in model — overslaan
# 'genereus' niet in model — overslaan
# 'telefonisch' niet in model — overslaan
# 'levensgevaarlijk' niet in model — overslaan
# 'vloeibaar' niet in model — overslaan
# 'aristocratisch' niet in model — overslaan
# 'rebel' niet in model — overslaan
# 'ordinair' niet in model — overslaan
# 'astmatisch' niet in model — overslaan
# 'scherpzinnig' niet in model — overslaan
# 'getalenteerd' niet in model — overslaan
# 'zuinig' niet in model — overslaan
# 'moe' niet in model — overslaan
# 'continu' niet in model — overslaan
# 'vooruitstrevend' niet in model — overslaan
# 'achterdochtig' niet in model — overslaan
# 'boosaardig' niet in model — overslaan
# 'strijdlustig' niet in model — overslaan
# 'kalm' niet in model — overslaan
# 'chaotisch' niet in model — overslaan
# 'godvruchtig' niet in model — overslaan
# 'hartstochtelijk' niet in model — overslaan
# 'ingewikkeld' niet in model — overslaan
# 'hoerig' niet in model — overslaan
# 'onwaardig' niet in model — overslaan
# 'ongeduldig' niet in model — overslaan
# 'doelbewust' niet in model — overslaan
# 'ongemakkelijk' niet in model — overslaan
# 'uitvoerig' niet in model — overslaan
# 'vindingrijk' niet in model — overslaan
# 'imaginair' niet in model — overslaan
# 'ongedeerd' niet in model — overslaan
# 'voelbaar' niet in model — overslaan
# 'indirect' niet in model — overslaan
# 'weergaloos' niet in model — overslaan
# 'foeilelijk' niet in model — overslaan
# 'wonderbaarlijk' niet in model — overslaan
# 'lenig' niet in model — overslaan
# 'statistisch' niet in model — overslaan
# 'medeplichtig' niet in model — overslaan
# 'groezelig' niet in model — overslaan
# 'vlijtig' niet in model — overslaan
# 'inhalig' niet in model — overslaan
# 'hartgrondig' niet in model — overslaan
# 'zinnelijk' niet in model — overslaan
# 'onwetend' niet in model — overslaan
# 'trouweloos' niet in model — overslaan
# 'behoedzaam' niet in model — overslaan
# 'onrechtmatig' niet in model — overslaan
# 'cultiveren' niet in model — overslaan
# 'voorlijk' niet in model — overslaan
# 'tolerant' niet in model — overslaan
# 'kleinzielig' niet in model — overslaan
# 'dogmatisch' niet in model — overslaan
# 'rijkelijk' niet in model — overslaan
# 'retorisch' niet in model — overslaan
# 'immoreel' niet in model — overslaan
# 'slaafs' niet in model — overslaan
# 'komisch' niet in model — overslaan
# 'onverminderd' niet in model — overslaan
# 'lijdzaam' niet in model — overslaan
# 'schrander' niet in model — overslaan
# 'hermetisch' niet in model — overslaan
# 'klagerig' niet in model — overslaan
# 'sprakeloos' niet in model — overslaan
# 'zachtzinnig' niet in model — overslaan
# 'overjarig' niet in model — overslaan
# 'vreugdeloos' niet in model — overslaan
# 'sceptisch' niet in model — overslaan
# 'toornig' niet in model — overslaan
# 'betrekkelijk' niet in model — overslaan
# 'onverdacht' niet in model — overslaan
# 'verderfelijk' niet in model — overslaan
# 'onevenwichtig' niet in model — overslaan
# 'razendsnel' niet in model — overslaan
# 'verachtelijk' niet in model — overslaan
# 'bloeddorstig' niet in model — overslaan
# 'solistisch' niet in model — overslaan
# 'logistiek' niet in model — overslaan
# 'onveranderlijk' niet in model — overslaan
# 'kostbaar' niet in model — overslaan
# 'gedurig' niet in model — overslaan
# 'geometrisch' niet in model — overslaan
# 'mals' niet in model — overslaan
# 'pijnloos' niet in model — overslaan
# 'effectief' niet in model — overslaan
# 'geruisloos' niet in model — overslaan
# 'onprettig' niet in model — overslaan
# 'masochistisch' niet in model — overslaan
# 'onzorgvuldig' niet in model — overslaan
# 'betamelijk' niet in model — overslaan
# 'onredelijk' niet in model — overslaan
# 'vreemdsoortig' niet in model — overslaan
# 'onstuitbaar' niet in model — overslaan
# 'satirisch' niet in model — overslaan
# 'geldig' niet in model — overslaan
# 'inhoudsloos' niet in model — overslaan
# 'krenterig' niet in model — overslaan
# 'discutabel' niet in model — overslaan
# 'irrationeel' niet in model — overslaan
# 'meervoudig' niet in model — overslaan
# 'aanstellerig' niet in model — overslaan
# 'inhoudelijk' niet in model — overslaan
# 'onaanzienlijk' niet in model — overslaan
# 'sfeervol' niet in model — overslaan
# 'harmonieus' niet in model — overslaan
# 'triestig' niet in model — overslaan
# 'incorrect' niet in model — overslaan
# 'fleurig' niet in model — overslaan
# 'sporadisch' niet in model — overslaan
# 'macaber' niet in model — overslaan
# 'jong' niet in model — overslaan
# 'oud' niet in model — overslaan
# 'gewoon' niet in model — overslaan
# 'minderjarig' niet in model — overslaan
# 'vaak' niet in model — overslaan
# 'dood' niet in model — overslaan
# 'lang' niet in model — overslaan
# 'kaal' niet in model — overslaan
# 'technisch' niet in model — overslaan
# 'vast' niet in model — overslaan
# 'gelijk' niet in model — overslaan
# 'wereldwijd' niet in model — overslaan
# 'actief' niet in model — overslaan
# 'dominant' niet in model — overslaan
# 'gevoelig' niet in model — overslaan
# 'zachtaardig' niet in model — overslaan
# 'tenger' niet in model — overslaan
# 'precies' niet in model — overslaan
# 'integer' niet in model — overslaan
# 'fris' niet in model — overslaan
# 'economisch' niet in model — overslaan
# 'vorig' niet in model — overslaan
# 'militair' niet in model — overslaan
# 'liefdevol' niet in model — overslaan
# 'geliefd' niet in model — overslaan
# 'klaar' niet in model — overslaan
# 'ondernemen' niet in model — overslaan
# 'dom' niet in model — overslaan
# 'haags' niet in model — overslaan
# 'indiaans' niet in model — overslaan
# 'verleidelijk' niet in model — overslaan
# 'flamboyant' niet in model — overslaan
# 'toffe' niet in model — overslaan
# 'mexicaans' niet in model — overslaan
# 'dun' niet in model — overslaan
# 'seksueel' niet in model — overslaan
# 'vierkant' niet in model — overslaan
# 'sportief' niet in model — overslaan
# 'wonderlijk' niet in model — overslaan
# 'stoute' niet in model — overslaan
# 'vrijwillig' niet in model — overslaan
# 'hitsig' niet in model — overslaan
# 'stout' niet in model — overslaan
# 'protestants' niet in model — overslaan
# 'doodsbang' niet in model — overslaan
# 'onverwacht' niet in model — overslaan
# 'strafbaar' niet in model — overslaan
# 'plots' niet in model — overslaan
# 'spannend' niet in model — overslaan
# 'goedmoedig' niet in model — overslaan
# 'inlands' niet in model — overslaan
# 'waardeloos' niet in model — overslaan
# 'goeiig' niet in model — overslaan
# 'goddelijk' niet in model — overslaan
# 'kwiek' niet in model — overslaan
# 'vroegrijp' niet in model — overslaan
# 'knorrig' niet in model — overslaan
# 'mondain' niet in model — overslaan
# 'kuis' niet in model — overslaan
# 'achterlijk' niet in model — overslaan
# 'speels' niet in model — overslaan
# 'gigantisch' niet in model — overslaan
# 'maatschappelijk' niet in model — overslaan
# 'jihadistisch' niet in model — overslaan
# 'wraakzuchtig' niet in model — overslaan
# 'luid' niet in model — overslaan
# 'intens' niet in model — overslaan
# 'enigmatisch' niet in model — overslaan
# 'onmachtig' niet in model — overslaan
# 'burgerlijk' niet in model — overslaan
# 'vermaard' niet in model — overslaan
# 'iel' niet in model — overslaan
# 'tof' niet in model — overslaan
# 'recent' niet in model — overslaan
# 'stellig' niet in model — overslaan
# 'springerig' niet in model — overslaan
# 'onverstoorbaar' niet in model — overslaan
# 'uitstekend' niet in model — overslaan
# 'sensitief' niet in model — overslaan
# 'monsterlijk' niet in model — overslaan
# 'jeugdig' niet in model — overslaan
# 'massief' niet in model — overslaan
# 'oninteressant' niet in model — overslaan
# 'mexicaan' niet in model — overslaan
# 'wetenschappelijk' niet in model — overslaan
# 'slavisch' niet in model — overslaan
# 'recalcitrant' niet in model — overslaan
# 'barmhartig' niet in model — overslaan
# 'onkreukbaar' niet in model — overslaan
# 'nietig' niet in model — overslaan
# 'spookachtig' niet in model — overslaan
# 'straffeloos' niet in model — overslaan
# 'verwerpelijk' niet in model — overslaan
# 'paradoxaal' niet in model — overslaan
# 'ijverig' niet in model — overslaan
# 'weerbarstig' niet in model — overslaan
# 'exclusief' niet in model — overslaan
# 'primitief' niet in model — overslaan
# 'patriarchaal' niet in model — overslaan
# 'elitair' niet in model — overslaan
# 'melig' niet in model — overslaan
# 'gedistingeerd' niet in model — overslaan
# 'onvoorwaardelijk' niet in model — overslaan
# 'moreel' niet in model — overslaan
# 'ontroostbaar' niet in model — overslaan
# 'zelfzuchtig' niet in model — overslaan
# 'supersterk' niet in model — overslaan
# 'puberaal' niet in model — overslaan
# 'middelgroot' niet in model — overslaan
# 'driedimensionaal' niet in model — overslaan
# 'alomtegenwoordig' niet in model — overslaan
# 'ondernemend' niet in model — overslaan
# 'consistent' niet in model — overslaan
# 'aktief' niet in model — overslaan
# 'dartel' niet in model — overslaan
# 'apetrots' niet in model — overslaan
# 'smoezelig' niet in model — overslaan
# 'pedant' niet in model — overslaan
# 'zwoel' niet in model — overslaan
# 'chronisch' niet in model — overslaan
# 'moordend' niet in model — overslaan
# 'doorslaggevend' niet in model — overslaan
# 'fabelachtig' niet in model — overslaan
# 'benijdenswaardig' niet in model — overslaan
# 'goedkoop' niet in model — overslaan
# 'adequaat' niet in model — overslaan
# 'aanspreekbaar' niet in model — overslaan
# 'obsessief' niet in model — overslaan
# 'vorstelijk' niet in model — overslaan
# 'houterig' niet in model — overslaan
# 'overtollig' niet in model — overslaan
# 'respectloos' niet in model — overslaan
# 'onbetaalbaar' niet in model — overslaan
# 'probleemloos' niet in model — overslaan
# 'cerebraal' niet in model — overslaan
# 'moorddadig' niet in model — overslaan
# 'dartele' niet in model — overslaan
# 'goedkoper' niet in model — overslaan
# 'vier' niet in model — overslaan
# 'abrupt' niet in model — overslaan
# 'mopperig' niet in model — overslaan
# 'toxisch' niet in model — overslaan
# 'hoogstpersoonlijk' niet in model — overslaan
# 'inschikkelijk' niet in model — overslaan
# 'pruisisch' niet in model — overslaan
# 'vulgair' niet in model — overslaan
# 'sletterig' niet in model — overslaan
# 'paralympisch' niet in model — overslaan
# 'pinnig' niet in model — overslaan
# 'vruchteloos' niet in model — overslaan
# 'statutair' niet in model — overslaan
# 'minuscuul' niet in model — overslaan
# 'afzichtelijk' niet in model — overslaan
# 'verlokkelijk' niet in model — overslaan
# 'stoutmoedig' niet in model — overslaan
# 'vluchtig' niet in model — overslaan
# 'vriendschappelijk' niet in model — overslaan
# 'onschadelijk' niet in model — overslaan
# 'rumoerig' niet in model — overslaan
# 'innovatief' niet in model — overslaan
# 'onvoordelig' niet in model — overslaan
# 'modderig' niet in model — overslaan
# 'onoverwinnelijk' niet in model — overslaan
# 'lichtvoetig' niet in model — overslaan
# 'elektrisch' niet in model — overslaan
# 'nichterig' niet in model — overslaan
# 'fiscaal' niet in model — overslaan
# 'glashelder' niet in model — overslaan
# 'versuft' niet in model — overslaan
# 'preciezer' niet in model — overslaan
# 'langgerekt' niet in model — overslaan
# 'onderhorig' niet in model — overslaan
# 'sec' niet in model — overslaan
# 'nauwlettend' niet in model — overslaan
# 'onverstandig' niet in model — overslaan
# 'luchtig' niet in model — overslaan
# 'fluwelig' niet in model — overslaan
# 'onneembaar' niet in model — overslaan
# 'misantropisch' niet in model — overslaan
# 'tweetalig' niet in model — overslaan
# 'ongerept' niet in model — overslaan
# 'pikant' niet in model — overslaan
# 'lafhartig' niet in model — overslaan
# 'staatloos' niet in model — overslaan
# 'ieel' niet in model — overslaan
# 'plezant' niet in model — overslaan
# 'ongekleed' niet in model — overslaan
# 'theologisch' niet in model — overslaan
# 'smetteloos' niet in model — overslaan
# 'inadequaat' niet in model — overslaan
# 'klein' niet in model — overslaan
# 'juist' niet in model — overslaan
# 'hoog' niet in model — overslaan
# 'extra' niet in model — overslaan
# 'huidig' niet in model — overslaan
# 'rustig' niet in model — overslaan
# 'raar' niet in model — overslaan
# 'grijs' niet in model — overslaan
# 'verantwoordelijk' niet in model — overslaan
# 'eigenlijk' niet in model — overslaan
# 'voorbij' niet in model — overslaan
# 'gelovig' niet in model — overslaan
# 'bezig' niet in model — overslaan
# 'eerlijk' niet in model — overslaan
# 'joviaal' niet in model — overslaan
# 'ruim' niet in model — overslaan
# 'link' niet in model — overslaan
# 'regelmatig' niet in model — overslaan
# 'beschaafd' niet in model — overslaan
# 'onwel' niet in model — overslaan
# 'links' niet in model — overslaan
# 'jaloers' niet in model — overslaan
# 'capabel' niet in model — overslaan
# 'afstandelijk' niet in model — overslaan
# 'dromerig' niet in model — overslaan
# 'blij' niet in model — overslaan
# 'fysiek' niet in model — overslaan
# 'stelselmatig' niet in model — overslaan
# 'historisch' niet in model — overslaan
# 'nationaal' niet in model — overslaan
# 'krom' niet in model — overslaan
# 'welbespraakt' niet in model — overslaan
# 'uniek' niet in model — overslaan
# 'mondig' niet in model — overslaan
# 'langzaam' niet in model — overslaan
# 'onnodig' niet in model — overslaan
# 'gewillig' niet in model — overslaan
# 'blijkbaar' niet in model — overslaan
# 'egocentrisch' niet in model — overslaan
# 'kansarm' niet in model — overslaan
# 'neurotisch' niet in model — overslaan
# 'rondborstig' niet in model — overslaan
# 'minderwaardig' niet in model — overslaan
# 'ongrijpbaar' niet in model — overslaan
# 'kwalijk' niet in model — overslaan
# 'gewetenloos' niet in model — overslaan
# 'onverwachts' niet in model — overslaan
# 'mobiel' niet in model — overslaan
# 'brutaal' niet in model — overslaan
# 'artistiek' niet in model — overslaan
# 'pragmatisch' niet in model — overslaan
# 'ongewoon' niet in model — overslaan
# 'stabiel' niet in model — overslaan
# 'wereldberoemd' niet in model — overslaan
# 'beweeglijk' niet in model — overslaan
# 'stads' niet in model — overslaan
# 'gretig' niet in model — overslaan
# 'nobel' niet in model — overslaan
# 'jammer' niet in model — overslaan
# 'impulsief' niet in model — overslaan
# 'ogenschijnlijk' niet in model — overslaan
# 'dankbaar' niet in model — overslaan
# 'vroegtijdig' niet in model — overslaan
# 'minzaam' niet in model — overslaan
# 'zwaaien' niet in model — overslaan
# 'heus' niet in model — overslaan
# 'schraal' niet in model — overslaan
# 'superieur' niet in model — overslaan
# 'alledaags' niet in model — overslaan
# 'geel' niet in model — overslaan
# 'bewonderenswaardig' niet in model — overslaan
# 'heerszuchtig' niet in model — overslaan
# 'griezelig' niet in model — overslaan
# 'vergeefs' niet in model — overslaan
# 'arbeidsongeschikt' niet in model — overslaan
# 'consequent' niet in model — overslaan
# 'cruciaal' niet in model — overslaan
# 'authentiek' niet in model — overslaan
# 'racistisch' niet in model — overslaan
# 'eerzuchtig' niet in model — overslaan
# 'drastisch' niet in model — overslaan
# 'overweldigend' niet in model — overslaan
# 'onpeilbaar' niet in model — overslaan
# 'rechteloos' niet in model — overslaan
# 'ongecompliceerd' niet in model — overslaan
# 'snugger' niet in model — overslaan
# 'ongeloofwaardig' niet in model — overslaan
# 'zedig' niet in model — overslaan
# 'compromisloos' niet in model — overslaan
# 'dommig' niet in model — overslaan
# 'langzamer' niet in model — overslaan
# 'glorieus' niet in model — overslaan
# 'oersterk' niet in model — overslaan
# 'vlug' niet in model — overslaan
# 'excellent' niet in model — overslaan
# 'warrig' niet in model — overslaan
# 'zwaaiend' niet in model — overslaan
# 'bedrijvig' niet in model — overslaan
# 'misdadig' niet in model — overslaan
# 'rap' niet in model — overslaan
# 'imbeciele' niet in model — overslaan
# 'denkbaar' niet in model — overslaan
# 'hol' niet in model — overslaan
# 'inwendig' niet in model — overslaan
# 'concreet' niet in model — overslaan
# 'onzuiver' niet in model — overslaan
# 'kunstmatig' niet in model — overslaan
# 'onaanvaardbaar' niet in model — overslaan
# 'moedwillig' niet in model — overslaan
# 'luthers' niet in model — overslaan
# 'extrovert' niet in model — overslaan
# 'kleurig' niet in model — overslaan
# 'exemplarisch' niet in model — overslaan
# 'onbeleefd' niet in model — overslaan
# 'bokkig' niet in model — overslaan
# 'nederlandstalig' niet in model — overslaan
# 'lichtbruin' niet in model — overslaan
# 'abnormaal' niet in model — overslaan
# 'haaks' niet in model — overslaan
# ...
# 'fysiologisch' niet in model — overslaan
# 'stoerder' niet in model — overslaan
# 'hypocriet' niet in model — overslaan
# 'privaat' niet in model — overslaan
# 'weigerachtig' niet in model — overslaan
# 'aantoonbaar' niet in model — overslaan
# 'informeel' niet in model — overslaan
# 'onjuist' niet in model — overslaan
# 'geweldloos' niet in model — overslaan
# 'afbreekbaar' niet in model — overslaan
# 'geluidloos' niet in model — overslaan
# 'ongebreideld' niet in model — overslaan
# 'contractueel' niet in model — overslaan
# 'bovendeks' niet in model — overslaan
# 'eenzijdig' niet in model — overslaan
# 'wreed' niet in model — overslaan
# 'schatplichtig' niet in model — overslaan
# 'idolaat' niet in model — overslaan
# 'eendrachtig' niet in model — overslaan
# 'feilloos' niet in model — overslaan
# 'opzichtig' niet in model — overslaan
# 'eenmalig' niet in model — overslaan
# 'onwaarschijnlijk' niet in model — overslaan
# 'ambigu' niet in model — overslaan
# 'categorisch' niet in model — overslaan
# 'ongetemd' niet in model — overslaan
# 'plakkerig' niet in model — overslaan
# 'onstabiel' niet in model — overslaan
# 'federaal' niet in model — overslaan
# 'kortaffe' niet in model — overslaan
# 'magerder' niet in model — overslaan
# 'gluiperig' niet in model — overslaan
# 'onbestaanbaar' niet in model — overslaan
# 'tjokvol' niet in model — overslaan
# 'onwelvoeglijk' niet in model — overslaan
# 'onverantwoord' niet in model — overslaan
# 'desolaat' niet in model — overslaan
# 'eufemistisch' niet in model — overslaan
# 'renommeren' niet in model — overslaan
# 'lompe' niet in model — overslaan
# 'nieuw' niet in model — overslaan
# 'bejaard' niet in model — overslaan
# 'heilig' niet in model — overslaan
# 'nodig' niet in model — overslaan
# 'toenmalig' niet in model — overslaan
# 'verkeerd' niet in model — overslaan
# 'beroemd' niet in model — overslaan
# 'blind' niet in model — overslaan
# 'aantrekkelijk' niet in model — overslaan
# 'bekend' niet in model — overslaan
# 'geweldig' niet in model — overslaan
# 'krachtig' niet in model — overslaan
# 'afkomstig' niet in model — overslaan
# 'succesvol' niet in model — overslaan
# 'agressief' niet in model — overslaan
# 'slecht' niet in model — overslaan
# 'deftig' niet in model — overslaan
# 'warm' niet in model — overslaan
# 'indonesisch' niet in model — overslaan
# 'duidelijk' niet in model — overslaan
# 'verliefd' niet in model — overslaan
# 'bewust' niet in model — overslaan
# 'crimineel' niet in model — overslaan
# 'geestig' niet in model — overslaan
# 'psychotisch' niet in model — overslaan
# 'gemakkelijk' niet in model — overslaan
# 'feministisch' niet in model — overslaan
# 'labiel' niet in model — overslaan
# 'vitaal' niet in model — overslaan
# 'heerlijk' niet in model — overslaan
# 'laag' niet in model — overslaan
# 'hedendaags' niet in model — overslaan
# 'zichtbaar' niet in model — overslaan
# 'onwettig' niet in model — overslaan
# 'baardig' niet in model — overslaan
# 'zwak' niet in model — overslaan
# 'rationeel' niet in model — overslaan
# 'morsig' niet in model — overslaan
# 'letterlijk' niet in model — overslaan
# 'opzettelijk' niet in model — overslaan
# 'robuust' niet in model — overslaan
# 'praktisch' niet in model — overslaan
# 'daadkrachtig' niet in model — overslaan
# 'eigengereid' niet in model — overslaan
# 'laffe' niet in model — overslaan
# 'losbandig' niet in model — overslaan
# 'liberaal' niet in model — overslaan
# 'principieel' niet in model — overslaan
# 'herhaaldelijk' niet in model — overslaan
# 'begripvol' niet in model — overslaan
# 'assertief' niet in model — overslaan
# 'schaars' niet in model — overslaan
# 'stijlvol' niet in model — overslaan
# 'voltijds' niet in model — overslaan
# 'ziekelijk' niet in model — overslaan
# 'verwijfd' niet in model — overslaan
# 'ontelbaar' niet in model — overslaan
# 'dyslectisch' niet in model — overslaan
# 'verkeren' niet in model — overslaan
# 'herkenbaar' niet in model — overslaan
# 'onvergetelijk' niet in model — overslaan
# 'pedoseksueel' niet in model — overslaan
# 'zwaarmoedig' niet in model — overslaan
# 'zogenaamd' niet in model — overslaan
# 'victoriaans' niet in model — overslaan
# 'glamoureus' niet in model — overslaan
# 'negatief' niet in model — overslaan
# 'eindeloos' niet in model — overslaan
# 'doodeng' niet in model — overslaan
# 'heftig' niet in model — overslaan
# 'incompetent' niet in model — overslaan
# 'scherp' niet in model — overslaan
# 'hoogstwaarschijnlijk' niet in model — overslaan
# 'veerkrachtig' niet in model — overslaan
# 'puur' niet in model — overslaan
# 'zorgvuldig' niet in model — overslaan
# 'noodzakelijk' niet in model — overslaan
# 'minimaal' niet in model — overslaan
# 'negatiever' niet in model — overslaan
# 'gering' niet in model — overslaan
# 'realistisch' niet in model — overslaan
# 'ontoerekeningsvatbaar' niet in model — overslaan
# 'groots' niet in model — overslaan
# 'strijdvaardig' niet in model — overslaan
# 'ideologisch' niet in model — overslaan
# 'valse' niet in model — overslaan
# 'revolutionair' niet in model — overslaan
# 'significant' niet in model — overslaan
# 'meegaand' niet in model — overslaan
# 'recht' niet in model — overslaan
# 'baanbrekend' niet in model — overslaan
# 'intensief' niet in model — overslaan
# 'wijd' niet in model — overslaan
# 'vals' niet in model — overslaan
# 'ongevoelig' niet in model — overslaan
# 'geil' niet in model — overslaan
# 'prompt' niet in model — overslaan
# 'sierlijk' niet in model — overslaan
# 'archetypisch' niet in model — overslaan
# 'dagenlang' niet in model — overslaan
# 'moeiteloos' niet in model — overslaan
# 'zwakkere' niet in model — overslaan
# 'hoorbaar' niet in model — overslaan
# 'logisch' niet in model — overslaan
# 'nutteloos' niet in model — overslaan
# 'waardevol' niet in model — overslaan
# 'lollig' niet in model — overslaan
# 'ondenkbaar' niet in model — overslaan
# 'achterbaks' niet in model — overslaan
# 'apathisch' niet in model — overslaan
# 'doordeweeks' niet in model — overslaan
# 'frontaal' niet in model — overslaan
# 'geneeskundig' niet in model — overslaan
# 'grafisch' niet in model — overslaan
# 'klakkeloos' niet in model — overslaan
# 'verwaand' niet in model — overslaan
# 'mondeling' niet in model — overslaan
# 'kleingeestig' niet in model — overslaan
# 'geaard' niet in model — overslaan
# 'kerngezond' niet in model — overslaan
# 'dubieus' niet in model — overslaan
# 'voltallig' niet in model — overslaan
# 'noodlottig' niet in model — overslaan
# 'noordelijk' niet in model — overslaan
# 'psychologisch' niet in model — overslaan
# 'evolutionair' niet in model — overslaan
# 'immaterieel' niet in model — overslaan
# 'theoretisch' niet in model — overslaan
# 'oneerlijk' niet in model — overslaan
# 'relevant' niet in model — overslaan
# 'grootmoedig' niet in model — overslaan
# 'borstelig' niet in model — overslaan
# 'ongeremd' niet in model — overslaan
# 'fenomenaal' niet in model — overslaan
# 'behendig' niet in model — overslaan
# 'onappetijtelijk' niet in model — overslaan
# 'onbreekbaar' niet in model — overslaan
# 'natuurkundig' niet in model — overslaan
# 'universeel' niet in model — overslaan
# 'scheel' niet in model — overslaan
# 'sarcastisch' niet in model — overslaan
# 'flitsen' niet in model — overslaan
# 'handmatig' niet in model — overslaan
# 'merkbaar' niet in model — overslaan
# 'barbaars' niet in model — overslaan
# 'functioneel' niet in model — overslaan
# 'kerkelijk' niet in model — overslaan
# 'overheersen' niet in model — overslaan
# 'trillerig' niet in model — overslaan
# 'kortharig' niet in model — overslaan
# 'drachtig' niet in model — overslaan
# 'flauw' niet in model — overslaan
# 'prudent' niet in model — overslaan
# 'geurig' niet in model — overslaan
# 'rekenkundig' niet in model — overslaan
# 'oververhit' niet in model — overslaan
# 'spierwit' niet in model — overslaan
# 'erbarmelijk' niet in model — overslaan
# 'gevoelvol' niet in model — overslaan
# 'uitdrukkingsloos' niet in model — overslaan
# 'meesterlijk' niet in model — overslaan
# 'westelijk' niet in model — overslaan
# 'honds' niet in model — overslaan
# 'schaar' niet in model — overslaan
# 'virusvrij' niet in model — overslaan
# 'amusant' niet in model — overslaan
# 'hypothetisch' niet in model — overslaan
# 'schreeuwerig' niet in model — overslaan
# 'bovenmenselijk' niet in model — overslaan
# 'nationalistisch' niet in model — overslaan
# 'stijfkoppig' niet in model — overslaan
# 'onleesbaar' niet in model — overslaan
# 'wrakkig' niet in model — overslaan
# 'klungelig' niet in model — overslaan
# 'bevreesd' niet in model — overslaan
# 'vreesachtig' niet in model — overslaan
# 'zurig' niet in model — overslaan
# 'indonesische' niet in model — overslaan
# 'globaal' niet in model — overslaan
# 'ouderloos' niet in model — overslaan
# 'aftands' niet in model — overslaan
# 'laf' niet in model — overslaan
# 'zwart' niet in model — overslaan
# 'rijk' niet in model — overslaan
# 'allochtone' niet in model — overslaan
# 'goed' niet in model — overslaan
# 'blond' niet in model — overslaan
# 'ziek' niet in model — overslaan
# 'vriendelijk' niet in model — overslaan
# 'islamitisch' niet in model — overslaan
# 'belangrijk' niet in model — overslaan
# 'schoon' niet in model — overslaan
# 'kwetsbaar' niet in model — overslaan
# 'heel' niet in model — overslaan
# 'allochtoon' niet in model — overslaan
# 'aziatisch' niet in model — overslaan
# 'autoritair' niet in model — overslaan
# 'fijn' niet in model — overslaan
# 'christelijk' niet in model — overslaan
# 'werkloos' niet in model — overslaan
# 'terecht' niet in model — overslaan
# 'centraal' niet in model — overslaan
# 'plotseling' niet in model — overslaan
# 'kort' niet in model — overslaan
# 'bewusteloos' niet in model — overslaan
# 'lokaal' niet in model — overslaan
# 'eigenzinnig' niet in model — overslaan
# 'broos' niet in model — overslaan
# 'best' niet in model — overslaan
# 'onvruchtbaar' niet in model — overslaan
# 'dagelijks' niet in model — overslaan
# 'rijp' niet in model — overslaan
# 'enthousiast' niet in model — overslaan
# 'rijpe' niet in model — overslaan
# 'scandinavisch' niet in model — overslaan
# 'paraat' niet in model — overslaan
# 'intellectueel' niet in model — overslaan
# 'voluptueus' niet in model — overslaan
# 'lui' niet in model — overslaan
# 'onaardig' niet in model — overslaan
# 'steevast' niet in model — overslaan
# 'langharig' niet in model — overslaan
# 'woedend' niet in model — overslaan
# 'gul' niet in model — overslaan
# 'modebewust' niet in model — overslaan
# 'degelijk' niet in model — overslaan
# 'vlot' niet in model — overslaan
# 'uiteenlopen' niet in model — overslaan
# 'hardvochtig' niet in model — overslaan
# 'spoorloos' niet in model — overslaan
# 'uiteenlopend' niet in model — overslaan
# 'welvarend' niet in model — overslaan
# 'menselijk' niet in model — overslaan
# 'bonkig' niet in model — overslaan
# 'publiekelijk' niet in model — overslaan
# 'ontredderd' niet in model — overslaan
# 'formidabel' niet in model — overslaan
# 'onberekenbaar' niet in model — overslaan
# 'wezenlijk' niet in model — overslaan
# 'luie' niet in model — overslaan
# 'buitengewoon' niet in model — overslaan
# 'arisch' niet in model — overslaan
# 'exotisch' niet in model — overslaan
# 'fel' niet in model — overslaan
# 'neutraal' niet in model — overslaan
# 'handtastelijk' niet in model — overslaan
# 'zwakzinnig' niet in model — overslaan
# 'koel' niet in model — overslaan
# 'amicaal' niet in model — overslaan
# 'fraai' niet in model — overslaan
# 'harteloos' niet in model — overslaan
# 'uitbundig' niet in model — overslaan
# 'bitter' niet in model — overslaan
# 'haastig' niet in model — overslaan
# 'verbaal' niet in model — overslaan
# 'bekwaam' niet in model — overslaan
# 'ongenaakbaar' niet in model — overslaan
# 'overbodig' niet in model — overslaan
# 'schichtig' niet in model — overslaan
# 'moedeloos' niet in model — overslaan
# 'bont' niet in model — overslaan
# 'primair' niet in model — overslaan
# 'slaperig' niet in model — overslaan
# 'academisch' niet in model — overslaan
# 'eerbaar' niet in model — overslaan
# 'gevoelloos' niet in model — overslaan
# 'openbaar' niet in model — overslaan
# 'huiselijk' niet in model — overslaan
# 'stom' niet in model — overslaan
# 'ritmisch' niet in model — overslaan
# 'lichtzinnig' niet in model — overslaan
# 'schriftelijk' niet in model — overslaan
# 'doodstil' niet in model — overslaan
# 'gunstig' niet in model — overslaan
# 'narrig' niet in model — overslaan
# 'grotesk' niet in model — overslaan
# 'prikkelbaar' niet in model — overslaan
# 'onhebbelijk' niet in model — overslaan
# 'dorps' niet in model — overslaan
# 'erotisch' niet in model — overslaan
# 'razend' niet in model — overslaan
# 'edel' niet in model — overslaan
# 'vraatzuchtig' niet in model — overslaan
# 'koddig' niet in model — overslaan
# 'onbuigzaam' niet in model — overslaan
# 'nuttig' niet in model — overslaan
# 'beeldig' niet in model — overslaan
# 'nalatig' niet in model — overslaan
# 'representatief' niet in model — overslaan
# 'allergisch' niet in model — overslaan
# 'optimaal' niet in model — overslaan
# 'explosief' niet in model — overslaan
# 'miezerig' niet in model — overslaan
# 'complementair' niet in model — overslaan
# 'statisch' niet in model — overslaan
# 'fantasierijk' niet in model — overslaan
# 'zweverig' niet in model — overslaan
# 'dramatisch' niet in model — overslaan
# 'onwrikbaar' niet in model — overslaan
# 'ontredderen' niet in model — overslaan
# 'voorspelbaar' niet in model — overslaan
# 'magisch' niet in model — overslaan
# 'brozer' niet in model — overslaan
# 'onbesuisd' niet in model — overslaan
# 'stedelijk' niet in model — overslaan
# 'diepgaand' niet in model — overslaan
# 'potsierlijk' niet in model — overslaan
# 'bangelijk' niet in model — overslaan
# 'venijnig' niet in model — overslaan
# 'zieker' niet in model — overslaan
# 'apostolisch' niet in model — overslaan
# 'trefzeker' niet in model — overslaan
# 'afgunstig' niet in model — overslaan
# 'onderhevig' niet in model — overslaan
# 'welbewust' niet in model — overslaan
# 'traumatisch' niet in model — overslaan
# 'daaropvolgend' niet in model — overslaan
# 'onpartijdig' niet in model — overslaan
# 'vlotter' niet in model — overslaan
# 'schaapachtig' niet in model — overslaan
# 'bevoegd' niet in model — overslaan
# 'onderhoudsarm' niet in model — overslaan
# 'wiskundig' niet in model — overslaan
# 'nostalgisch' niet in model — overslaan
# 'kruidig' niet in model — overslaan
# 'waakzaam' niet in model — overslaan
# 'hilarisch' niet in model — overslaan
# 'filosofisch' niet in model — overslaan
# 'angelsaksisch' niet in model — overslaan
# 'beducht' niet in model — overslaan
# 'thematisch' niet in model — overslaan
# 'knuffelbaar' niet in model — overslaan
# 'onmenselijk' niet in model — overslaan
# 'ondoordringbaar' niet in model — overslaan
# 'schurkachtig' niet in model — overslaan
# 'binnenlands' niet in model — overslaan
# Totaal aantal berekende bias-waarden: 0
# Totaal aantal berekende bias-waarden: 0
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/v_/ypb5b1nx079dj_hcjyz0t47c0000gn/T/ipykernel_91316/3868876089.py in ?()
#      50 individual_bias = compute_individual_bias(adjectives=filtered_adjectives, male_terms=MALE_WORDS, female_terms=FEMALE_WORDS, model=model)
#      51 print(f"Totaal aantal berekende bias-waarden: {len(individual_bias)}")
#      52
#      53     # Sorteer oplopend op 'bias_value'
# ---> 54 df_sorted = individual_bias.sort_values("bias_value", ascending=True)
#      55
#      56     # Selecteer de 30 laagste scores
#      57 lowest_30 = df_sorted.head(30)
#
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7185             )
#    7186         elif len(by):
#    7187             # len(by) == 1
#    7188
# -> 7189             k = self._get_label_or_level_values(by[0], axis=axis)
#    7190
#    7191             # need to rewrap column in Series to apply key function
#    7192             if key is not None:
#
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, key, axis)
#    1907             values = self.xs(key, axis=other_axes[0])._values
#    1908         elif self._is_level_reference(key, axis=axis):
#    1909             values = self.axes[axis].get_level_values(key)._values
#    1910         else:
# -> 1911             raise KeyError(key)
#    1912
#    1913         # Check for duplicates
#    1914         if values.ndim > 1:
#
# KeyError: 'bias_value'

# %%
individual_bias_dict = individual_bias.set_index("word")["bias_value"].to_dict()
search_words = ["sterk", "zacht", "moedig", "emotioneel", "dominant", 
                "zorgzaam", "aardig", "knap", "schattig"]

print("Bias scores voor specifieke woorden:")
for word in search_words:
    # Let op: als je bij de filtering alles lowercase hebt gemaakt, doe je hier ook word.lower()
    w_lower = word.lower()
    bias_value = individual_bias_dict.get(w_lower)

    if bias_value is not None:
        print(f"{word}: {bias_value:.3f}")
    else:
        print(f"{word}: Niet gevonden in df_bias (of model).")

# %%
# Debugging print statements
print(f"Number of adjectives (filtered_lemmas): {len(filtered_adjectives)}")

# Define the query
query = Query(
    target_sets=[
        ["man", "kerel", "jongen", "vader", "zoon", "vent", "meneer", "opa", "oom"],
        ["vrouw", "dame", "meisje", "moeder", "dochter", "tante", "oma", "mevrouw", "meid"]],
    attribute_sets=[filtered_adjectives],  # Ensure it's a list of lists
    target_sets_names=["Male Terms", "Female Terms"],
    attribute_sets_names=["Adjectives"],
)

# Instantiate the metric and run the query
ripa = RIPA()
result = ripa.run_query(query, nl_model)

# Print results
print(result)

# %%
# 'result["word_values"]' bevat nu een dictionary {woord: {'mean': x, 'std': y}, ...}
# Daar kunnen we een DataFrame van maken:
df_ripa = pd.DataFrame({
    'Word': result["word_values"].keys(),
    'Mean Score': [val['mean'] for val in result["word_values"].values()],
    'Std Dev': [val['std'] for val in result["word_values"].values()],
})

# Sorteer op Mean Score (die RIPA per woord toekent) en bekijk
df_ripa = df_ripa.sort_values(by="Mean Score", ascending=False).reset_index(drop=True)
for word in search_words:
    if word in result["word_values"]:
        mean_val = result["word_values"][word]["mean"]
        std_val = result["word_values"][word]["std"]
        print(f"{word}: Mean={mean_val:.3f}, Std={std_val:.3f}")
    else:
        print(f"{word}: niet gevonden in RIPA-result.")

# %%
# 1) Voeg een Z-score-kolom toe:
mean_of_scores = df_ripa["Mean Score"].mean()
std_of_scores = df_ripa["Mean Score"].std()

df_ripa["Z-Score"] = (df_ripa["Mean Score"] - mean_of_scores) / std_of_scores

# 2) Als je daarna wilt sorteren op Z-Score (hoog -> laag), doe je:
df_ripa = df_ripa.sort_values("Z-Score", ascending=False).reset_index(drop=True)

# 3) Print de eerste rijen om te zien hoe de Z-scores eruitzien:
print(df_ripa.head(10))
print(df_ripa.tail(10))
